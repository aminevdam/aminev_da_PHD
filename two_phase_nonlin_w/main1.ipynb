# %% [markdown]
# ## Two phase flow.
# ### pezoflow equation.
#
# $$\frac{\partial \rho_w S_w m}{\partial t} + \frac{\partial}{\partial x}(\rho_w W_w)=0$$
# $$\frac{\partial \rho_o S_o m}{\partial t} + \frac{\partial}{\partial x}(\rho_o W_o)=0$$
# $$W_w=-\frac{k_{rw} k}{\mu_w}\frac{\partial p}{\partial x}$$
# $$W_o=-\frac{k_{ro} k}{\mu_o}\frac{\partial p}{\partial x}$$
# $$S_o+S_w=1$$
# $$m(p)=m_0+\beta_r*(p-p_0)$$
# $$\rho_{w,o}(p) = \rho_{w0, o0}(1 + \beta_{w,o}*(p-p_0))$$
#
# $$x\in[0,L]$$
# $$t\in[0,T]$$
#
# *Initial and boundary conditions*
# $$p(x, t=0)=p_0$$
# $$S_w(x, t=0)=S_{w0}$$
# $$W_w(x=0, t)=\frac{Q}{S}$$
# $$S_w(x=0, t)=1$$
# $$p(x=L, t)=p_0$$

# %% [markdown]
# 1.
# $$\rho_w m \frac{\partial S_w}{\partial t} + \rho_w S_w \frac{\partial m}{\partial t} + m S_w \frac{\partial \rho_w}{\partial t} - \frac{\partial}{\partial x}(\rho_w\frac{k_{rw} k}{\mu_w}\frac{\partial p}{\partial x})=0 $$
# $$\rho_o m \frac{\partial S_o}{\partial t} + \rho_w S_o \frac{\partial m}{\partial t} + m S_o \frac{\partial \rho_o}{\partial t} - \frac{\partial}{\partial x}(\rho_w\frac{k_{ro} k}{\mu_o}\frac{\partial p}{\partial x})=0 $$
#
# 2.
# $$ m \frac{\partial S_w}{\partial t} + S_w \beta_r \frac{\partial p}{\partial t} + m S_w \frac{\rho_{w0}}{\rho_w} \beta_w\frac{\partial p}{\partial t} - \frac{1}{\rho_w}\frac{\partial}{\partial x}(\rho_w\frac{k_{rw} k}{\mu_w}\frac{\partial p}{\partial x})=0 $$
# $$m \frac{\partial S_o}{\partial t} +  S_o \beta_r \frac{\partial p}{\partial t} + m S_o \frac{\rho_{o0}}{\rho_o} \beta_o\frac{\partial p}{\partial t} - \frac{1}{\rho_o}\frac{\partial}{\partial x}(\rho_o\frac{k_{ro} k}{\mu_o}\frac{\partial p}{\partial x})=0 $$

# %% [markdown]
# 3. summarize
# $$\frac{\partial p}{\partial t}(S_w \beta_r+(1-S_w) \beta_r + m S_w \frac{\rho_{w0}}{\rho_w} \beta_w+m (1-S_w) \frac{\rho_{o0}}{\rho_o} \beta_o) - \frac{1}{\rho_w}\frac{\partial}{\partial x}(k(\frac{k_{rw} \rho_w}{\mu_w})\frac{\partial p}{\partial x})-\frac{1}{\rho_o}\frac{\partial}{\partial x}(k(\frac{k_{ro} \rho_o}{\mu_o})\frac{\partial p}{\partial x})=0 $$
# $$ m \frac{\partial S_w}{\partial t} + S_w (\beta_r + m \frac{\rho_{w0}}{\rho_w} \beta_w) \frac{\partial p}{\partial t} - \frac{1}{\rho_w}\frac{\partial}{\partial x}(\rho_w\frac{k_{rw} k}{\mu_w}\frac{\partial p}{\partial x})=0 $$

# %% [markdown]
# 3. final
# $$\frac{\partial p}{\partial t}(\beta_r + m S_w \frac{\rho_{w0}}{\rho_w} \beta_w+m (1-S_w) \frac{\rho_{o0}}{\rho_o} \beta_o) - \frac{1}{\rho_w}\frac{\partial}{\partial x}(k(\frac{k_{rw} \rho_w}{\mu_w})\frac{\partial p}{\partial x})-\frac{1}{\rho_o}\frac{\partial}{\partial x}(k(\frac{k_{ro} \rho_o}{\mu_o})\frac{\partial p}{\partial x})=0 $$
# $$ m \frac{\partial S_w}{\partial t} + S_w (\beta_r + m \frac{\rho_{w0}}{\rho_w} \beta_w) \frac{\partial p}{\partial t} - \frac{1}{\rho_w}\frac{\partial}{\partial x}(\rho_w\frac{k_{rw} k}{\mu_w}\frac{\partial p}{\partial x})=0 $$

# %% [markdown]
# 4. non dimensional
#
# $$\overline{p} = \frac{p}{p_0}, \overline{t} = \frac{t}{T}, \overline{x} = \frac{x}{L}$$
#
# $$\frac{1}{\beta_r}\frac{\partial \overline{p}}{\partial \overline{t}}(\beta_r + m S_w \frac{\rho_{w0}}{\rho_w} \beta_w+m (1-S_w) \frac{\rho_{o0}}{\rho_o} \beta_o)
#
# - \frac{T}{\rho_w L^2 \beta_r}\frac{\partial}{\partial \overline{x}}(k(\frac{k_{rw} \rho_w}{\mu_w})\frac{\partial \overline{p}}{\partial \overline{p}})
#
# -\frac{T}{\rho_o L^2 \beta_r}\frac{\partial}{\partial \overline{x}}(k(\frac{k_{ro} \rho_o}{\mu_o})\frac{\partial \overline{p}}{\partial \overline{x}})=0 $$
# $$ m \frac{\partial S_w}{\partial \overline{t}}
#
# + S_w (\beta_r + m \frac{\rho_{w0}}{\rho_w} \beta_w) \frac{\partial \overline{p}}{\partial \overline{t}}p_0
#
# - \frac{p_0 T}{\rho_w L^2}\frac{\partial}{\partial \overline{x}}(\rho_w\frac{k_{rw} k}{\mu_w}\frac{\partial \overline{p}}{\partial \overline{x}})=0 $$

# %% [markdown]
# 5. bndry cond
#
# $$\frac{k_{rw} k p_0}{\mu_w L}\frac{\partial \overline{p}}{\partial \overline{x}} = \frac{Q}{S}$$
# $$\overline{p}=1$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.optimize import newton_krylov, fsolve, least_squares, root
from scipy.interpolate import interp1d
from sol_plot import solution_plot
from tqdm.notebook import tqdm
from scipy.optimize import minimize
import pickle
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt


def estimate_oscillation_parameters(t, y, time_delta=None):
    """
    Определяет параметры затухающих колебаний из данных с возможностью анализа выбранного интервала времени.
    
    Параметры:
    -----------
    data : np.ndarray
        Матрица с двумя столбцами: время и значения колебаний.
    time_delta : tuple (t0, t1), optional
        Интервал времени (в секундах), в котором нужно проанализировать данные. Если None, анализируются все данные.
        
    Возвращает:
    -----------
    dict : Словарь с параметрами A, γ, ω, φ
    """
    
    # Фильтрация данных по заданному интервалу времени
    if time_delta is not None:
        t0, t1 = time_delta
        mask = (t >= t0) & (t <= t1)
        t = t[mask]
        y = y[mask]

    if len(t) < 2:
        raise ValueError("Недостаточно данных в указанном интервале времени.")

    # Предварительная оценка циклической частоты через FFT
    n = len(t)
    dt = t[1] - t[0]  # Шаг времени
    fft_result = np.fft.fft(y - np.mean(y))  # Центрируем данные
    frequencies = np.fft.fftfreq(n, d=dt)
    peak_freq = abs(frequencies[np.argmax(np.abs(fft_result[:n // 2]))])
    omega_init = 2 * np.pi * peak_freq  # Циклическая частота

    # Модель функции колебаний
    def damped_oscillation(t, A, gamma, omega, phi):
        return A * np.exp(-gamma * t) * np.cos(omega * t + phi)

    # Начальные приближения для оптимизации
    A_init = np.max(y)
    gamma_init = 0.1  # Предположим слабое затухание
    phi_init = 0  # Без сдвига фазы на старте

    initial_guess = [A_init, gamma_init, omega_init, phi_init]

    # Подгонка данных
    params, _ = curve_fit(damped_oscillation, t, y, p0=initial_guess)
    A, gamma, omega, phi = params

    # Визуализация результата
    plt.figure(figsize=(10, 5))
    plt.plot(t, y, label='Исходные данные')
    plt.plot(t, damped_oscillation(t, A, gamma, omega, phi), label='Подгонка', linestyle='--')
    plt.legend()
    plt.xlabel('Время (s)')
    plt.ylabel('Амплитуда')
    plt.title(f'Подгонка затухающих колебаний в интервале ({t0}, {t1}) секунд' if time_delta else 'Подгонка затухающих колебаний')
    plt.show()

    # Возвращаем параметры
    return A, gamma, omega, phi


def expit(x):
    try:
        return 1 / (1 + np.exp(-x))
    except:
        return 0.


k_water = lambda x: 0.6*(x)**2
k_oil = lambda x: 0.2*(x-1)**2

dk_water = lambda x: 1.2*x
dk_oil = lambda x: 0.4*(x-1)

plt.plot(np.linspace(0,1,100), k_water(np.linspace(0,1,100)))
plt.plot(np.linspace(0,1,100), k_oil(np.linspace(0,1,100)))

# %%
class TwoPhase():
    def __init__(self,
                 mu_h,
                 mu_o,
                 glad,
                 G,
                 mu_h_w,
                 mu_h_w_b,
                 mu_o_w,
                 glad_w,
                 glad_w_b,
                 G_w,
                 G_w_b,
                 k,
                 m0,
                 beta_r,
                 rho_w0,
                 beta_w,
                 rho_o0,
                 beta_o,
                 t_0,
                 T,
                 nt,
                 tt,
                 pow_n,
                 alfa_k,
                 x_0,
                 L,
                 S,
                 nx,
                 p_0,
                 s_0,
                 s_left,
                 s_right,
                 mu_type_o,
                 mu_type_w,
                 p_left=None,
                 p_right=None,
                 Q=None) -> None:
        self.mu_h = mu_h
        self.mu_o = mu_o
        self.glad = glad
        self.G = G
        self.mu_h_w = mu_h_w
        self.mu_h_w_b = mu_h_w_b
        self.mu_o_w = mu_o_w
        self.glad_w = glad_w
        self.glad_w_b = glad_w_b
        self.G_w = G_w
        self.G_w_b = G_w_b
        self.k = k
        self.Q = Q
        self.m0 = m0
        self.beta_r = beta_r
        self.rho_w0 = rho_w0
        self.beta_w = beta_w
        self.rho_o0 = rho_o0
        self.beta_o = beta_o
        self.t_0 = t_0
        self.T = T
        self.nt = nt
        self.tt = tt
        self.pow_n = pow_n
        self.x_0 = x_0
        self.L = L
        self.nx = nx
        self.p_0 = p_0
        self.s_0 = s_0
        self.s_left = s_left
        self.s_right = s_right
        self.alfa_k = alfa_k
        self.time = np.linspace(t_0, T, int(nt), dtype=np.float64)/self.T
        self.dt = self.time[1]-self.time[0]
        self.tt = self.time.flat[np.abs(self.time - tt).argmin()]
        self.x = np.linspace(0, L, nx, dtype=np.float64)/self.L
        self.dx = self.x[1]-self.x[0]
        self.mu_oil_arr = []
        self.mu_water_arr = []
        self.grad_p = []
        self.grad_mu_o = []
        self.grad_mu_w = []
        self.mu_stop_o = np.zeros_like(self.x)
        self.mu_stop_w = np.zeros_like(self.x)
        if mu_type_o not in ["mu_2side", "mu_run", "mu"]:
            raise NameError
        self.mu_type_o = mu_type_o
        self.mu_type_w = mu_type_w
        self.p_left = p_left
        self.p_right = p_right
        self.S = S

    def m(self, p):
        return self.m0 + self.beta_r*(p*self.p_0-self.p_0)

    def rho_w(self, p):
        return self.rho_w0*(1+self.beta_w*(p*self.p_0-self.p_0))

    def rho_o(self, p):
        return self.rho_o0*(1+self.beta_o*(p*self.p_0-self.p_0))
    
    def mu_water(self, grad, grad_old, mu_stop_w):
        grad = abs(grad)*self.p_0/self.L
        grad_old = abs(grad_old)*self.p_0/self.L
        mu = (self.mu_h_w-self.mu_o_w) * expit (self.glad_w * (-grad + self.G_w)) + self.mu_o_w
        if self.mu_type_w=='mu_2side':
            mu_new = (self.mu_h_w_b-self.mu_o_w) * expit (self.glad_w_b * (-grad + self.G_w_b)) + self.mu_o_w
            res = np.where(mu<=self.mu_o_w, 1, 0)
            res = np.where(mu_stop_w+res>=1, 1, 0)
            result = np.where(res==1, mu_new, mu)
        elif self.mu_type_w=='mu_run':
            result = mu
            res = self.mu_stop_w
        elif self.mu_type_w=='mu_lin':
            result = np.ones_like(grad)*self.mu_o_w
            res = self.mu_stop_w
        else:
            res = np.where(grad>grad_old, grad, grad_old)
            result = (self.mu_h_w-self.mu_o_w) * expit (self.glad * (-res + self.G_w)) + self.mu_o_w
        return result, res

    def mu_oil(self, grad, grad_old, mu_stop_o):
        grad = abs(grad)*self.p_0/self.L
        grad_old = abs(grad_old)*self.p_0/self.L
        mu = (self.mu_h-self.mu_o) * expit (self.glad * (-grad + self.G)) + self.mu_o
        if self.mu_type_o=='mu_2side':
            mu_new = (self.mu_h/1. - self.mu_o) * expit (self.glad * (-grad + self.G/100)) + self.mu_o
            res = np.where(mu<=self.mu_o*1., 1, 0)
            res = np.where(mu_stop_o+res>=1, 1, 0)
            result = np.where(res==1, mu_new, mu)
        elif self.mu_type_o=='mu_run':
            result = mu
            res = None
        else:
            res = np.where(grad>grad_old, grad, grad_old)
            result = (self.mu_h-self.mu_o) * expit (self.glad * (-res + self.G)) + self.mu_o
        return result, res

    def rate(self, t):
        n = self.pow_n
        t = t*self.T
        tt = self.tt*self.T
        a = self.Q*(self.T-self.t_0) / (tt**(n+1)/(n+1) + tt**n*(self.T-tt))
        # if t<1.5:
        return np.where(t<tt,a*t**(n),a*tt**(n))
        # else:
        #     return -np.where(t<self.tt,a*t**(n),a*self.tt**(n))

    def lam_w(self, s, p, grad, grad_old, mu):
        return self.k*k_water(s)*self.rho_w(p) / self.mu_water(grad, grad_old, mu)[0]

    def lam_o(self, s, p, grad, grad_old, mu):
        return self.k*k_oil(s)*self.rho_o(p) / self.mu_oil(grad, grad_old, mu)[0]

    def coef_dp_dt(self, p, s):
        return self.beta_r + self.m(p)*s*self.beta_w*self.rho_w0/self.rho_w(p)+\
                   self.m(p)*(1-s)*self.beta_o*self.rho_o0/self.rho_o(p)

    def s_function(self, t):
        """
        Функция, изменяющая s по линейному закону до t=tt, 
        после чего s фиксируется на уровне s1.

        :param t: текущее время
        :param tt: пороговое время
        :param s0: начальное значение s
        :param s1: конечное значение s
        :return: значение s в момент времени t
        """
        if t < self.tt:
            return self.s_0 + (self.s_left - self.s_0) * (t / self.tt)
        else:
            return self.s_left

    def solution_init(self):
        p = np.zeros((self.nt, self.nx), dtype=np.float64)
        p[0, :] = self.p_0/self.p_0

        s = np.zeros((self.nt, self.nx), dtype=np.float64)
        s[0,:] = self.s_0
        s[:,0] = [self.s_function(i) for i in self.time]
        return p, s

    def grad(self, p, dx, axis='center'):
        res = np.ones_like(p)
        if axis=='left':
            res[1:] = (p[1:]-p[:-1])/dx
            res[0] = (p[1]-p[0])/dx
        elif axis=='right':
            res[:-1] = (p[1:]-p[:-1])/dx
            res[-1] = (p[-1]-p[-2])/dx
        else:
            res = np.gradient(p, dx, edge_order=1)
        return res

    def residual(self, u_new, u_old, s_old, t_step, dt, dx):
        """Выражение невязки для метода Ньютона-Крылова."""
        N = len(u_new)
        res = np.zeros(N, dtype=np.float64)
        grad = self.grad(u_new, self.dx)
        grad_old = self.grad_p[-1]
        k_left_w = self.lam_w(s_old[1:-1], u_new[1:-1], grad[1:-1], grad_old[1:-1], self.mu_stop_w[1:-1])
        k_right_w = self.lam_w(s_old[2:], u_new[2:], grad[2:], grad_old[2:], self.mu_stop_w[2:])

        k_left_o = self.lam_o(s_old[1:-1], u_new[1:-1], grad[1:-1], grad_old[1:-1], self.mu_stop_o[1:-1])
        k_right_o = self.lam_o(s_old[2:], u_new[2:], grad[2:], grad_old[2:], self.mu_stop_o[2:])


        res[1:-1] = 1*self.coef_dp_dt(u_new[1:-1], s_old[1:-1])*(u_new[1:-1] - u_old[1:-1]) / dt - \
                    self.T/(self.rho_w(u_new[1:-1])*self.L**2)*(k_right_w*(u_new[2:] - u_new[1:-1]) / dx**2 - k_left_w*(u_new[1:-1] - u_new[:-2]) / dx**2) -\
                    self.T/(self.rho_o(u_new[1:-1])*self.L**2)*(k_right_o*(u_new[2:] - u_new[1:-1]) / dx**2 - k_left_o*(u_new[1:-1] - u_new[:-2]) / dx**2)

        # Граничные условия
        if self.p_left is not None:
            res[0] = u_new[0] - self.p_left/self.p_0
        else:
            # res[0] = -grad[0] + 8e+6/self.p_0*self.L
            res[0] = self.p_0/self.L*grad[0] * k_water(s_old[0])* self.k / self.mu_water(grad[0], grad_old[0], self.mu_stop_w[0])[0]*self.S + self.rate(t_step)
        res[-1] = u_new[-2] - self.p_right/self.p_0

        return res

    # Метод Ньютона-Крылова для решения нелинейной системы
    def solve_nonlinear(self, u_old, s_old, t_step, dt, dx):
        """Решение системы уравнений с использованием метода Ньютона-Крылова."""
        u_new_guess = np.copy(u_old)  # начальное предположение
        u_new = newton_krylov(lambda u_new: self.residual(u_new, u_old, s_old, t_step, dt, dx), u_new_guess)
        # u_new = least_squares(lambda u_new: self.residual(u_new, u_old, s_old, t_step, dt, dx), u_new_guess, ).x
        # u_new = root(lambda u_new: self.residual(u_new, u_old, s_old, t_step, dt, dx), u_new_guess, method='krylov').x
        return u_new

    # Параметры фракционного потока
    def fw(self, s, p, grad, grad_old, mu_w):
        """ Функция фракционного потока воды """
        grad = self.grad(p, self.dx)

        return self.lam_w(s, p, grad, grad_old, mu_w) * grad


    def exact(self, t):
        Swi0 = self.s_0
        self.mu_water0 = self.mu_o*1.1
        def f(sat):
            return k_water(sat)/(k_water(sat)+self.mu_water0/self.mu_o*k_oil(sat))

        def df(sat):
            return (dk_water(sat)*(k_water(sat)+self.mu_water0/self.mu_o*k_oil(sat))-k_water(sat)*(dk_water(sat)+self.mu_water0/self.mu_o*dk_oil(sat)))/(k_water(sat)+self.mu_water0/self.mu_o*k_oil(sat))**2

        def opt(sat):
            return f(sat)-f(Swi0)-df(sat)*(sat-Swi0)

        Sc = fsolve(opt, 0.5)[0]
        Xc = self.Q/self.m0*(f(Sc)-f(Swi0))/(Sc-Swi0)*t
        Sx1 = np.zeros(200)
        X1 = np.zeros(200)
        Sx2 = np.zeros(200)
        X2 = np.zeros(200)
        Sx1[0] = 1
        Sx2[0] = Swi0
        X2[0] = Xc
        for i in range(1,200):
            Sx1[i] = Sx1[i-1]-(1-Sc)/199 
            Sx2[i] = Swi0
            X2[i] = X2[i-1] + (self.L+1e-3-Xc)/199
        for i in range(1,200):
            X1[i] = self.Q/self.m0 * df(Sx1[i]) * t
        X3 = np.array([Xc, Xc])
        Sx3 = np.array([Sc, Swi0])
        return np.concatenate((X1,X3,X2)), np.concatenate((Sx1,Sx3,Sx2))


    def solve(self):
        p, s = self.solution_init()
        s_buckley = np.zeros_like(s)
        s_buckley[0,:] = s[0,:]
        mu_oil_init = np.zeros(self.nx, dtype=np.float64)+self.mu_h
        mu_water_init = np.zeros(self.nx, dtype=np.float64)+self.mu_h*1.5
        self.mu_oil_arr.append(mu_oil_init)
        self.mu_water_arr.append(mu_water_init)
        self.grad_p.append(self.grad(p[0,:], self.dx))
        self.grad_mu_o.append(self.grad(p[0,:], self.dx))
        self.grad_mu_w.append(self.grad(p[0,:], self.dx))
        # Решение системы с использованием Ньютона-Крылова
        for t, t_step in tqdm(enumerate(self.time[:-1]), total=self.time.shape[0], desc="Processing"):
            # решение уравнения для давления
            p_old = p[t, :].copy()
            s_old = s[t, :].copy()
            p_new = self.solve_nonlinear(p_old, s_old, t_step, self.dt, self.dx)
            p[t+1, :] = p_new.copy()
            grad_new = np.gradient(p_new, self.dx)
            grad_old = np.gradient(p_old, self.dx)
            # решение уравнения для насыщенности
            fw_val = self.fw(s_old, p_new, grad_new, grad_old, self.mu_stop_w)
            s_new = np.zeros_like(s[t,:], dtype=np.float64)
            s_new[1:-1] = s_old[1:-1] + self.dt*self.p_0*self.T/(self.rho_w(p_new[1:-1])*self.m(p_new[1:-1])*self.dx*self.L**2) * (fw_val[1:-1] - fw_val[:-2]) - s_old[1:-1]*self.p_0*(self.beta_r/self.m(p_new[1:-1]) + self.beta_w*self.rho_w0/self.rho_w(p_new[1:-1]))*(p_new[1:-1]-p_old[1:-1])
            # s_new[1:-1] = np.where(s_new[1:-1]>1, 1, s_new[1:-1])
            # s_new[1:-1] = np.where(s_new[1:-1]<0, 0, s_new[1:-1])
            # s_new[0] = self.s_function(t_step)
            # s_new[0] = s_new[1]
            s_new[-1] = s_new[-2]
            s[t+1,1:] = s_new[1:].copy()

            mu_oil_new, res_o = self.mu_oil(grad_new, self.grad_mu_o[-1], self.mu_stop_o)
            mu_water_new, res_w = self.mu_water(grad_new, self.grad_mu_w[-1], self.mu_stop_w)
            self.mu_stop_o = res_o
            self.mu_stop_w = res_w
            self.grad_mu_o.append(res_o*self.L/self.p_0)
            self.grad_mu_w.append(res_w*self.L/self.p_0)
            self.grad_p.append(grad_new)
            self.mu_oil_arr.append(mu_oil_new)
            self.mu_water_arr.append(mu_water_new)
            x_b, s_b = self.exact(t_step*self.T)
            x_b = x_b/self.L
            func = interp1d(x_b, s_b, kind='nearest')
            s_b = func(self.x)
            s_buckley[t+1, :] = s_b
        self.mu_oil_arr = np.array(self.mu_oil_arr)
        self.mu_water_arr = np.array(self.mu_water_arr)
        self.grad_p = np.array(self.grad_p)
        self.grad_mu_o = np.array(self.grad_mu_o)
        self.grad_mu_w = np.array(self.grad_mu_w)

        self.p = p
        self.s = s
        return p, s, x_b, s_buckley

# %%
mu_h = 10e-3
mu_o = 2e-3
glad = 0.00004
G = 0.4e7

# %%
import numpy as np
import pandas as pd
import json
import os
from two_phase import estimate_damping_from_peak_difference, analyze_oscillations


# Определяем интервалы параметров
param_ranges = {
    "Q": [0.1, 0.8],
    "mu_h_w": [20e-3, 10e-2],  # (0.1, 0.02)
    "mu_h_w_b": [20e-3, 10e-2], # (0.1, 0.02)
    "mu_o_w": [mu_o/1.5, mu_o*1.5],
    "glad_w": [0.00004 * 0.06, 0.00004 * 1.5],
    "glad_w_b": [0.00004 * 0.06, 0.00004 * 1.5]
}

# Функция для генерации случайных параметров
def generate_random_params():
    mu_h_w = np.random.uniform(*param_ranges["mu_h_w"])  # Генерируем mu_h_w
    mu_h_w_b = np.random.uniform(param_ranges["mu_h_w_b"][0], mu_h_w)  # mu_h_w_b ≤ mu_h_w
    mu_o_w = np.random.uniform(param_ranges["mu_o_w"][0], min(mu_h_w, mu_h_w_b, mu_o*1.5))

    return {
        "mu_h": mu_h,
        "mu_o": mu_o,
        "glad": glad/4,
        "G": G,
        "mu_h_w": mu_h_w,
        "mu_h_w_b": mu_h_w_b,
        "mu_o_w": mu_o_w,
        "glad_w": np.random.uniform(*param_ranges["glad_w"]),
        "glad_w_b": np.random.uniform(*param_ranges["glad_w_b"]),
        "G_w": G*1.5,
        "G_w_b": G,
        "k": 10e-15,
        "Q": np.random.uniform(*param_ranges["Q"])/86400,
        "m0": 0.2,
        "beta_r": 1.e-10,
        "rho_w0": 990.,
        "beta_w": 5e-9, # посмотреть в таблице
        "rho_o0": 800.,
        "beta_o": 8e-9, # посмотреть в таблице
        "t_0": 0,
        "T": 20.*86400,
        "nt": 150*36,
        "tt": 0.01,
        "pow_n": 2,
        "alfa_k": 1e-9,
        "x_0": 0,
        "L" : 101,
        "S": 1,
        "nx": 100,
        "p_0": 1e+6,
        "p_right": 1e+6,
        "s_0": 0,
        "s_left": 1.,
        "s_right": 1,
        "mu_type_o": "mu",
        "mu_type_w": "mu_2side"
    }

csv_file = "exp_res/experiments_results1.csv"
json_file = "exp_res/experiments_results.json"


# Запуск 100 экспериментов
experiments = []
for i in range(100):
    params = generate_random_params()
    model = TwoPhase(**params)
    try:
        p1, s1, x_b, s_b = model.solve()
    except:
        print("Error with solve")
        continue
    G1 = -np.ones_like(model.grad_p)*model.G
    x1 = model.x*model.L
    p1 = p1 * model.p_0
    x_b = x_b*model.L
    grad_p1 = model.grad_p*model.p_0/model.L

    sx = 0.6
    time_delta = (0.5, 1)

    w_water1 = -model.k*k_water(s1)/model.mu_water_arr*grad_p1
    w_oil1 = -model.k*k_oil(s1)/model.mu_oil_arr*grad_p1

    sx = 20*sx
    sx = np.abs(model.x*model.L - sx).argmin()

    Q_in1 = w_water1[:,0]*model.S
    Qw_out1 = w_water1[:,sx]*model.S
    Qo_out1 = w_oil1[:,sx]*model.S

    Q_in_sum1 = [0]
    Qw_out_sum1 = [0]
    Qo_out_sum1 = [0]
    for q_in_w, q_o, q_w in zip(Q_in1, Qo_out1, Qw_out1):
        Q_in_sum1.append(Q_in_sum1[-1]+q_in_w)
        Qw_out_sum1.append(Qw_out_sum1[-1]+q_w)
        Qo_out_sum1.append(Qo_out_sum1[-1]+q_o)

    V_in_sum1 = [q*(model.S*model.L*model.m0) for q in Q_in_sum1]

    alfa_w, A_w, A_end_w = estimate_damping_from_peak_difference(model.time, Qw_out1, time_delta, interval_fraction=0.09)
    alfa_o, A_o, A_end_o = estimate_damping_from_peak_difference(model.time, Qo_out1, time_delta, interval_fraction=0.09)
    A0_w, freq_w = analyze_oscillations(model.time, Qw_out1, time_delta)
    A0_o, freq_o = analyze_oscillations(model.time, Qo_out1, time_delta)

    # Объединяем входные данные и результаты
    experiment_data = {
        "mu_h_w": params["mu_h_w"],
        "mu_h_w_b": params["mu_h_w_b"],
        "mu_o_w": params["mu_o_w"],
        "glad_w": params["glad_w"],
        "glad_w_b": params["glad_w_b"],
        "alfa_w": alfa_w,
        "A_w": A_w,
        'A_end_w': A_end_w,
        "freq_w": freq_w,
        "alfa_o": alfa_o,
        "A_o": A_o,
        'A_end_o': A_end_o,
        "freq_o": freq_o,
        "Q": params["Q"]
        }

    # Добавляем в CSV
    df = pd.DataFrame([experiment_data])
    df.to_csv(csv_file, mode='a', header=False, index=False)

    # Добавляем в JSON (построчно)
    if os.path.exists(json_file):
        with open(json_file, "r+") as f:
            data = json.load(f)
            data.append(experiment_data)
            f.seek(0)
            json.dump(data, f, indent=4)
    else:
        with open(json_file, "w") as f:
            json.dump([experiment_data], f, indent=4)

print("✅ Эксперименты завершены! Данные сохранены в JSON и CSV.")

# %%
solver1 = TwoPhase(
                mu_h = mu_h,
                mu_o = mu_o,
                glad = glad/4,
                G = G,
                mu_h_w = mu_h*10,
                mu_h_w_b = mu_h*10,
                mu_o_w = mu_o/1.5,
                glad_w = glad*0.8,
                glad_w_b= glad*1.5,
                G_w = G*1.5,
                G_w_b = G,
                k = 10e-15,
                Q = 0.3/86400,
                m0 = 0.2,
                beta_r = 1.e-10,
                rho_w0 = 990.,
                beta_w = 5e-9, # посмотреть в таблице
                rho_o0 = 800.,
                beta_o = 8e-9, # посмотреть в таблице
                t_0 = 0,
                T = 20.*86400,
                nt = 150*36,
                tt = 0.01,
                pow_n = 2,
                alfa_k=1e-9,
                x_0 = 0,
                L = 101,
                S = 1,
                nx = 100,
                p_0 = 1e+6,
                p_right=1e+6,
                s_0 = 0,
                s_left = 1.,
                s_right = 1,
                mu_type_o = "mu",
                mu_type_w="mu_2side")

p1, s1, x_b, s_b = solver1.solve()

# with open("exp_res/solver1.pkl", "wb") as f:
#     pickle.dump(solver1, f)

G1 = -np.ones_like(solver1.grad_p)*solver1.G
x1 = solver1.x*solver1.L
p1 = p1 * solver1.p_0
x_b1 = x_b*solver1.L
grad_p1 = solver1.grad_p*solver1.p_0/solver1.L

# %%
sx = 0.6
time_delta = (0.5, 1)

w_water1 = -solver1.k*k_water(s1)/solver1.mu_water_arr*grad_p1
w_oil1 = -solver1.k*k_oil(s1)/solver1.mu_oil_arr*grad_p1

sx = 20*sx
sx = np.abs(solver1.x*solver1.L - sx).argmin()

Q_in1 = w_water1[:,0]*solver1.S
Qw_out1 = w_water1[:,sx]*solver1.S
Qo_out1 = w_oil1[:,sx]*solver1.S

Q_in_sum1 = [0]
Qw_out_sum1 = [0]
Qo_out_sum1 = [0]
for q_in_w, q_o, q_w in zip(Q_in1, Qo_out1, Qw_out1):
    Q_in_sum1.append(Q_in_sum1[-1]+q_in_w)
    Qw_out_sum1.append(Qw_out_sum1[-1]+q_w)
    Qo_out_sum1.append(Qo_out_sum1[-1]+q_o)

V_in_sum1 = [q*(solver1.S*solver1.L*solver1.m0) for q in Q_in_sum1]

from two_phase import estimate_damping_from_peak_difference, analyze_oscillations
alfa_w, A_w, A_end_w = estimate_damping_from_peak_difference(solver1.time, Qw_out1, time_delta, interval_fraction=0.08)
A0, freq = analyze_oscillations(solver1.time, Qw_out1, time_delta)
print(alfa_w, A_w, A_end_w)
print(A0, freq)

# %%
solver2 = TwoPhase(
                mu_h = mu_h,
                mu_o = mu_o,
                glad = glad/4,
                G = G,
                mu_h_w = mu_h*2,
                mu_h_w_b = mu_h*2,
                mu_o_w = mu_o/1.5,
                glad_w = glad*0.1,
                glad_w_b = glad*0.05,
                G_w = G*1.5,
                G_w_b=G,
                k = 10e-15,
                Q = 0.3/86400,
                m0 = 0.2,
                beta_r = 1.e-10,
                rho_w0 = 990.,
                beta_w = 5e-9, # посмотреть в таблице
                rho_o0 = 800.,
                beta_o = 8e-9, # посмотреть в таблице
                t_0 = 0,
                T = 17.*86400,
                nt = 150*36,
                tt = 0.01,
                pow_n = 2,
                alfa_k=1e-9,
                x_0 = 0,
                L = 101,
                S = 1,
                nx = 102,
                p_0 = 1e+6,
                p_right=1e+6,
                s_0 = 0,
                s_left = 1.,
                s_right = 1,
                mu_type_o = "mu",
                mu_type_w="mu_2side")

p2, s2, x_b, s_b = solver2.solve()

with open("exp_res/solver2.pkl", "wb") as f:
    pickle.dump(solver2, f)

G2 = -np.ones_like(solver2.grad_p)*solver2.G
x2 = solver2.x*solver2.L
p2 = p2 * solver2.p_0
x_b2 = x_b*solver2.L
grad_p2 = solver2.grad_p*solver2.p_0/solver2.L

# %%
solver3 = TwoPhase(
                mu_h = mu_h,
                mu_o = mu_o,
                glad = glad/4,
                G = G,
                mu_h_w = mu_h*10,
                mu_h_w_b = mu_h*10,
                mu_o_w = mu_o/1.5,
                glad_w = glad*0.8,
                glad_w_b = glad*0.05,
                G_w = G*1.5,
                G_w_b=G,
                k = 10e-15,
                Q = 0.3/86400,
                m0 = 0.2,
                beta_r = 1.e-10,
                rho_w0 = 990.,
                beta_w = 5e-9, # посмотреть в таблице
                rho_o0 = 800.,
                beta_o = 8e-9, # посмотреть в таблице
                t_0 = 0,
                T = 15.*86400,
                nt = 150*36,
                tt = 0.01,
                pow_n = 2,
                alfa_k=1e-9,
                x_0 = 0,
                L = 101,
                S = 1,
                nx = 102,
                p_0 = 1e+6,
                p_right=1e+6,
                s_0 = 0,
                s_left = 1.,
                s_right = 1,
                mu_type_o = "mu",
                mu_type_w="mu_2side")

p3, s3, x_b, s_b = solver3.solve()

with open("exp_res/solver3.pkl", "wb") as f:
    pickle.dump(solver3, f)

G2 = -np.ones_like(solver2.grad_p)*solver2.G
x2 = solver2.x*solver2.L
p2 = p2 * solver2.p_0
x_b2 = x_b*solver2.L
grad_p2 = solver2.grad_p*solver2.p_0/solver2.L

# %%
solver2 = TwoPhase(
                mu_h = mu_h,
                mu_o = mu_o,
                glad = glad/4,
                G = G,
                mu_h_w = mu_h*10,
                mu_h_w_b = mu_h*1,
                mu_o_w = mu_o/1.5,
                glad_w = glad*0.8,
                glad_w_b = glad*0.08,
                G_w = G*1.5,
                G_w_b=G,
                k = 10e-15,
                Q = 0.3/86400,
                m0 = 0.2,
                beta_r = 1.e-14,
                rho_w0 = 990.,
                beta_w = 5e-14, # посмотреть в таблице
                rho_o0 = 800.,
                beta_o = 8e-14, # посмотреть в таблице
                t_0 = 0,
                T = 15.*86400,
                nt = 150*38,
                tt = 0.01,
                pow_n = 2,
                alfa_k=1e-9,
                x_0 = 0,
                L = 101,
                S = 1,
                nx = 99,
                p_0 = 1e+6,
                p_right=1e+6,
                s_0 = 0,
                s_left = 1.,
                s_right = 1,
                mu_type_o = "mu",
                mu_type_w="mu_2side")

p2, s2, x_b, s_b = solver2.solve()

# with open("exp_res/solver6.pkl", "wb") as f:
#     pickle.dump(solver6, f)

G2 = -np.ones_like(solver2.grad_p)*solver2.G
x2 = solver2.x*solver2.L
p2 = p2 * solver2.p_0
x_b2 = x_b*solver2.L
grad_p2 = solver2.grad_p*solver2.p_0/solver2.L

# %%
solution_plot([[x1, p1],
               [x1, s1],
               [x1, s_b],
               [x1, solver1.mu_oil_arr],
               [x1, solver1.mu_water_arr],
               [x1, abs(G1)],
               [x1, abs(G1)*1.5],
               [x1, abs(grad_p1)],
               [x1, -solver1.k*k_water(s1)/solver1.mu_water_arr*grad_p1],
               [x1, -solver1.k*k_oil(s1)/solver1.mu_oil_arr*grad_p1]],
               titles=("Pressure (p) vs x", "Saturation (s) vs x", "mu_oil", "grad(p)", 'w_water_oil'),
               idx=[[1,1], [1,2], [1,2], [2,1], [2,1], [2,2], [2,2], [2,2], [3,1], [3,1]],
               nt=solver1.nt,
               height=1000,
               width=1200,
               fraction=0.1)

# %% [markdown]
# ### вязкость от градиента

# %%
grad = np.linspace(0.2e7, 0.7e7, 200)
mu_oil = (solver1.mu_h-solver1.mu_o) * expit (solver1.glad * (-grad + solver1.G)) + solver1.mu_o


grad = np.linspace(0.2e7, 0.7e7, 200)
mu_water_f1 = (solver1.mu_h_w-solver1.mu_o_w) * expit (solver1.glad_w * (-grad + solver1.G_w)) + solver1.mu_o_w
mu_water_b1 = (solver1.mu_h_w_b-solver1.mu_o_w) * expit (solver1.glad_w_b * (-grad + solver1.G_w_b)) + solver1.mu_o_w
mu_water_f2 = (solver2.mu_h_w-solver2.mu_o_w) * expit (solver2.glad_w * (-grad + solver2.G_w)) + solver2.mu_o_w
mu_water_b2 = (solver2.mu_h_w_b-solver2.mu_o_w) * expit (solver2.glad_w_b * (-grad + solver2.G_w_b)) + solver2.mu_o_w
plt.plot(grad, mu_oil, label="mu_oil(grad)")
plt.plot(grad, mu_water_f1)
plt.plot(grad, mu_water_b1)
plt.plot(grad, mu_water_f2, '--')
plt.plot(grad, mu_water_b2, '--')
plt.legend()
plt.ylabel('mu_water, Pa*sec')
plt.xlabel("grad, Pa/m")
plt.title('mu_water(grad)')
plt.show()

# %% [markdown]
# ### Q(t)

# %%
w_water1 = -solver1.k*k_water(s1)/solver1.mu_water_arr*grad_p1
w_oil1 = -solver1.k*k_oil(s1)/solver1.mu_oil_arr*grad_p1

w_water2 = -solver2.k*k_water(s2)/solver2.mu_water_arr*grad_p2
w_oil2 = -solver2.k*k_oil(s2)/solver2.mu_oil_arr*grad_p2

sx = len(solver1.x)//10

Q_in1 = w_water1[:,0]*solver1.S
Qw_out1 = w_water1[:,sx]*solver1.S
Qo_out1 = w_oil1[:,sx]*solver1.S

Q_in2 = w_water2[:,0]*solver2.S
Qw_out2 = w_water2[:,sx]*solver2.S
Qo_out2 = w_oil2[:,sx]*solver2.S

Q_in_sum1 = [0]
Qw_out_sum1 = [0]
Qo_out_sum1 = [0]
for q_in_w, q_o, q_w in zip(Q_in1, Qo_out1, Qw_out1):
    Q_in_sum1.append(Q_in_sum1[-1]+q_in_w)
    Qw_out_sum1.append(Qw_out_sum1[-1]+q_w)
    Qo_out_sum1.append(Qo_out_sum1[-1]+q_o)

Q_in_sum2 = [0]
Qw_out_sum2 = [0]
Qo_out_sum2 = [0]
for q_in_w, q_o, q_w in zip(Q_in2, Qo_out2, Qw_out2):
    Q_in_sum2.append(Q_in_sum2[-1]+q_in_w)
    Qw_out_sum2.append(Qw_out_sum2[-1]+q_w)
    Qo_out_sum2.append(Qo_out_sum2[-1]+q_o)

V_in_sum1 = [q*(solver1.S*solver1.L*solver1.m0) for q in Q_in_sum1]
V_in_sum2 = [q*(solver2.S*solver2.L*solver2.m0) for q in Q_in_sum2]

plt.plot(V_in_sum1, Qw_out_sum1, '--', label='water1')
plt.plot(V_in_sum1, Qo_out_sum1, '--', label='oil1')
plt.plot(V_in_sum2, Qw_out_sum2, '--', label='water2')
plt.plot(V_in_sum2, Qo_out_sum2, '--', label='oil2')
plt.title(f"Накопленный объем добычи в сечении {sx} от времени")
plt.legend()
plt.show()
plt.plot(solver1.time, Qw_out1, '--', label='water1')
plt.plot(solver1.time, Qo_out1, '--', label='oil1')
plt.plot(solver2.time, Qw_out2, '--', label='water2')
plt.plot(solver2.time, Qo_out2, '--', label='oil2')
plt.title(f"Динамика добычи воды в сечении {sx} от времени")
plt.legend()
plt.show()
plt.plot(solver1.time, grad_p1[:,sx], '--', label='grad1')
plt.plot(solver2.time, grad_p2[:,sx], '--', label='grad2')
plt.title(f"Изменение градиента в сечении {sx} от времени")
plt.legend()
plt.show()
plt.plot(solver1.time[1:], solver1.mu_oil_arr[1:,sx], '--', label='mu_oil1')
plt.plot(solver1.time[1:], solver1.mu_water_arr[1:,sx], '--', label='mu_water1')
plt.plot(solver2.time[1:], solver2.mu_oil_arr[1:,sx], '--', label='mu_oil2')
plt.plot(solver2.time[1:], solver2.mu_water_arr[1:,sx], '--', label='mu_water2')
plt.title(f"Изменение вязкости фаз в сечении {sx} от времени")
plt.legend()
plt.show()

from scipy.signal import find_peaks

def find_peaks_in_ts(time, values, height_factor=0.3, distance_fraction=0.001, prominence_factor=0.05):
    """
    Находит пики во временном ряде и возвращает глобальные индексы исходного массива.

    :param time: Массив времени
    :param values: Массив значений функции
    :param time_delta: Интервал времени (t0, t1)
    :param height_factor: Фактор от максимальной амплитуды для минимальной высоты пика
    :param distance_fraction: Фракция от длины интервала для минимального расстояния между пиками
    :param prominence_factor: Фактор от максимальной амплитуды для выделенности пиков
    :return: Глобальные индексы пиков, значения пиков
    """

    # Автоматический расчет порогов
    max_amplitude = np.max(values)
    height = height_factor * max_amplitude
    distance = int(distance_fraction * len(time))
    prominence = prominence_factor * max_amplitude

    # Нахождение пиков
    peaks, _ = find_peaks(values, height=height, distance=distance, prominence=prominence)

    return peaks, values[peaks]


fig, ax1 = plt.subplots(figsize=(12, 6))

time_part = (solver2.time >= 0.5) & (solver2.time <= 1)
peaks, values = find_peaks_in_ts(solver2.time[time_part], Qw_out2[time_part])
# Первая ось (слева)
color = 'tab:blue'
ax1.set_xlabel('Время (с)')
ax1.set_ylabel('Объем добычи м3', color=color)
ax1.plot(solver2.time[time_part], Qw_out2[time_part], color=color, label='Вода')
ax1.plot(solver2.time[time_part], Qo_out2[time_part], color='tab:orange', label='Нефть')
for peak in peaks:
    ax1.axvline(solver2.time[time_part][peak], color='gray', linestyle='--')
ax1.tick_params(axis='y', labelcolor=color)

# Вторая ось (слева, с небольшим смещением)
ax2 = ax1.twinx()  # Дублируем ось Y
color2 = 'tab:green'
ax2.spines['left'].set_position(('axes', -0.1))  # Смещение оси внутрь графика
ax2.yaxis.set_label_position('left')
ax2.yaxis.tick_left()
ax2.set_ylabel('Вязкость Па*с', color=color2)
ax2.plot(solver2.time[time_part], solver2.mu_water_arr[time_part, sx], color=color2, linestyle='--', label='Вязкость')
ax2.tick_params(axis='y', labelcolor=color2)

# Вторая ось (справа)
ax3 = ax1.twinx()  # Создаём вторую ось, разделяющую ту же ось x
color = 'tab:red'
ax3.set_ylabel('градиент Па/м', color=color)
ax3.plot(solver2.time[time_part], abs(grad_p2[time_part, sx]), color=color, linestyle='-.', label='Градиент')
ax3.tick_params(axis='y', labelcolor=color)

# Добавление заголовка и легенды
fig.suptitle('График с двумя вертикальными осями')
fig.legend(loc='upper right', bbox_to_anchor=(0.85, 0.85))

# Отображение сетки и графика
plt.grid(True)
plt.show()

# %%
def exact(t):
    Swi0 = 0
    mu_water = 2e-3
    G1 = 0.3e7
    G2 = 0.4e7
    S = 1
    Q = 0.85/86400
    m = 0.2
    k = 10e-15
    mu_h_oil = 10e-3
    mu_l_oil = 2e-3
    mu_h_water = 8e-3
    mu_l_water = 1.8e-3
    L = 100

    def mu_f(sat):
        # print(sat)
        # print(Q/S)
        # print(G1*k*(k_water(sat)/mu_h_water+k_oil(sat)/mu_h_oil))
        # print(G1*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_h_oil))
        # print(G2*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_h_oil))
        # print(G2*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_l_oil))
        if Q/S <= G1*k*(k_water(sat)/mu_h_water+k_oil(sat)/mu_h_oil):
            print('+')
            return mu_h_water/mu_h_oil
        elif (Q/S >= G1*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_h_oil)) and (Q/S < G2*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_h_oil)):
            print('++')
            return mu_l_water/mu_h_oil
        elif Q/S >= G2*k*(k_water(sat)/mu_l_water+k_oil(sat)/mu_l_oil):
            print('+++')
            return mu_l_water/mu_l_oil
        else:
            return  -1
    plt.plot(np.linspace(0, 1, 100), [mu_f(i) for i in np.linspace(0,1,100)])
    plt.show()

    def f(sat):
        return k_water(sat)/(k_water(sat)+mu_f(sat)*k_oil(sat))

    def df(sat):
        return (dk_water(sat)*(k_water(sat)+mu_f(sat)*k_oil(sat))-k_water(sat)*(dk_water(sat)+mu_f(sat)*dk_oil(sat)))/(k_water(sat)+mu_f(sat)*k_oil(sat))**2

    def opt(sat):
        return f(sat)-f(Swi0)-df(sat)*(sat-Swi0)

    Sc = fsolve(opt, 0.5)[0]
    Xc = Q/m*(f(Sc)-f(Swi0))/(Sc-Swi0)*t
    Sx1 = np.zeros(200)
    X1 = np.zeros(200)
    Sx2 = np.zeros(200)
    X2 = np.zeros(200)
    Sx1[0] = 1
    Sx2[0] = Swi0
    X2[0] = Xc
    for i in range(1,200):
        Sx1[i] = Sx1[i-1]-(1-Sc)/199 
        Sx2[i] = Swi0
        X2[i] = X2[i-1] + (L+1e-3-Xc)/199
    for i in range(1,200):
        X1[i] = Q/m * df(Sx1[i]) * t
    X3 = np.array([Xc, Xc])
    Sx3 = np.array([Sc, Swi0])
    return np.concatenate((X1,X3,X2)), np.concatenate((Sx1,Sx3,Sx2))


x, S = exact(5*86400)

plt.plot(x, S)

# %%
import scipy.interpolate as spi
import numpy as np
import scipy
import scipy.optimize

class w_func:
    def __init__(self, x_vals, y_vals, k, kind='cubic'):
        """
        x_vals, y_vals - массивы значений аргумента и функции
        kind - тип интерполяции: 'linear', 'quadratic', 'cubic' и т.д.
        """
        self.x_vals = np.array(x_vals)
        self.y_vals = np.array(y_vals)
        self.k = k
        # Создаём интерполяционный сплайн
        self.spline = spi.interp1d(self.x_vals, self.y_vals, kind=kind, fill_value="extrapolate")
        self.func = lambda x: -self.k*k_water(x)/mu_water(self.spline(x))*self.spline(x)

    def __call__(self, x):
        """Возвращает значение интерполированной функции в точке x"""
        return self.func(x)

    def derivative(self, x, dx=1e-5):
        """Численно вычисляет производную в точке x методом конечных разностей"""
        if x <= self.x_vals[0]:
            return (self.func(x + dx) - self.func(x)) / (dx)
        elif x>= self.x_vals[-1]:
            return (self.func(x) - self.func(x - dx)) / (dx)
        else:
            return (self.func(x + dx) - self.func(x - dx)) / (2 * dx)


def mu_oil(grad):
    grad = abs(grad)
    G = 0.4e7
    mu_h = 10e-3
    mu_l = 2e-3
    B = 0.00004
    return (mu_h-mu_l) * expit (B * (-grad + G)) + mu_l

def mu_water(grad):
    grad = abs(grad)
    G = 0.3e7
    mu_h = 100e-3
    mu_l = 1.8e-3
    B = 0.000004
    return (mu_h-mu_l) * expit (B * (-grad + G)) + mu_l

def exact(t):
    Swi0 = 0
    S = 1
    Q = 0.1/86400
    m = 0.2
    k = 10e-15
    L = 100

    def grad_det(grad, sat):
        return 1e5*(-k*(k_water(sat)/mu_water(grad)+k_oil(sat)/mu_oil(grad))*grad - Q/S)

    def grad_sat(s0, s1):
        sat_arr = np.linspace(s0, s1, 300, endpoint=True)
        grad = [fsolve(grad_det, x0=1e+6, args=(i))[0] for i in sat_arr]
        return grad, sat_arr
    
    grad, sat_arr = grad_sat(Swi0, 1)
    plt.plot(sat_arr, grad)
    plt.title('grad(s)')
    plt.show()
    plt.plot(sat_arr, [mu_oil(i) for i in grad])
    plt.title('mu(s)')
    plt.show()
    plt.plot(grad, [mu_oil(i) for i in grad])
    plt.title('mu(grad)')
    plt.show()
    w1_func = w_func(sat_arr, grad, k)
    plt.plot(sat_arr, w1_func(sat_arr)/(Q/S))
    plt.title('w1(s)')
    plt.show()
    plt.plot(sat_arr, [w1_func.derivative(i) for i in sat_arr])
    plt.title('w1.grad(s)')
    plt.show()

    def opt(sat):
        return w1_func(sat)-w1_func(Swi0)-w1_func.derivative(sat)*(sat-Swi0)
    
    def opt1(sat):
        return -(w1_func(sat)-w1_func(Swi0))/(sat - Swi0)

    # Sc = fsolve(opt, x0=0.3)[0]
    Sc = scipy.optimize.minimize_scalar(opt1, bounds=(0,1))
    print(Sc)
    Sc = Sc.x
    Xc = 1/m*(w1_func(Sc)-w1_func(Swi0))/(Sc-Swi0)*t
    Sx1 = np.zeros(200)
    X1 = np.zeros(200)
    Sx2 = np.zeros(200)
    X2 = np.zeros(200)
    Sx1[0] = 1
    Sx2[0] = Swi0
    X2[0] = Xc
    for i in range(1,200):
        Sx1[i] = Sx1[i-1]-(1-Sc)/199 
        Sx2[i] = Swi0
        X2[i] = X2[i-1] + (L+1e-3-Xc)/199
    for i in range(1,200):
        X1[i] = 1/m * w1_func.derivative(Sx1[i]) * t
    X3 = np.array([Xc, Xc])
    Sx3 = np.array([Sc, Swi0])
    return np.concatenate((X1,X3,X2)), np.concatenate((Sx1,Sx3,Sx2))


x, S = exact(10*86400)

plt.plot(x, S)
plt.plot()
